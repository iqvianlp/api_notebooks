# %% [markdown]
# # IQVIA NLP - MedDRA
#
# ## API Description
# The unstructured format of reports relevant to safety (social media, call center notes, literature) makes Adverse Event Detection hard to capture.
#
# For Data Scientists, MedDRA NLP API solves this problem by offering a fast and accurate automated identification and coding of adverse events from a range of unstructured documents into standardized MedDRA concepts.
#
# ## Accessing the API
# In order to consume this API, you will first need to request access to the MedDRA NLP API via this link:
# https://api-marketplace.work.iqvia.com/s/communityapi/a085w00000zhFVAAA2/api-marketplaceiqvianlpmeddrapreview .
#
# Please refer to "API Documentation" to learn more about accessing and using the API.
#
# ## Notebook Description
# This notebook is designed to show users an example of using the MedDRA NLP API to identify and extract adverse events from medical documents into standardized MedDRA concepts.
#
# ### Authorization
# The instructions for getting your credentials and the API endpoint URL can be found under the section "Get Started" and "How to use the API" following this link: https://api-marketplace.work.iqvia.com/s/communityapi/a085w00000zhFVAAA2/api-marketplaceiqvianlpmeddrapreview

# %%
import getpass
import requests

# In this demo scenario, URL for US based customers
# api_marketplace_url = 'https://vt.us-rds.solutions.iqvia.com/meddra/api/v1/meddra/'
# In this demo scenario, URL for EU based customers
api_marketplace_url = 'https://vt.eu-apim.solutions.iqvia.com/eu/meddra/api/v1/meddra/'

mkp_user = input("Marketplace clientId: ")
mkp_password = getpass.getpass("Marketplace clientSecret: ")
mkp_headers = {'clientId': mkp_user, 'clientSecret': mkp_password}

# Check credentials by making a dummy request
print("Checking your credentials, please wait...")
response = requests.post(api_marketplace_url, headers=mkp_headers, files={'file': "test"})

if response.status_code == 200:
    print("Congratulations! Your credentials are accepted!")
else:
    raise Exception(f"Error: {response}")
# Out:
# Marketplace clientId: 96244db5b4fd4641a366068cd4e363b6
# Marketplace clientSecret: ········
# Checking your credentials, please wait...
# Congratulations! Your credentials are accepted!

# %% [markdown]
# ### Example one: Make a request with text string as input
# MedDRA NLP API expects the String as Request Data Type. This example shows how to make a request to the API with text strings as input.

# %%
import requests

# Define input text
input_text = "Local anesthetic medication was infiltrated around and into the area of interest. There was an obvious skin lesion there and this gentleman has a history of squamous cell carcinoma. A punch biopsy of the worrisome skin lesion was obtained with a portion of the normal tissue included. The predominant portion of the biopsy was of the lesion itself."

# Make a request
print("Posting text strings...")
response = requests.post(api_marketplace_url, headers=mkp_headers, files={'file': input_text})

# Check the response
if response.status_code == 200:
    print("Success!")
    body_json = response.json()
    print(f"Raw JSON response from the API is: {body_json}")
else:
    raise Exception(f"Error: {response}")
# Out:
# Posting text strings...
# Success!
# Raw JSON response from the API is: {'doc_id': 'file', 'results': [{'Certainty': {'logical_column_id': 0, 'value': ''}, '[PT] MedDRA PT': {'logical_column_id': 1, 'value': 'Skin lesion', 'original_spans_outer': [[103, 114]], 'original_spans_inner': [[103, 114]], 'indexed_spans_outer': [[4413, 4824]], 'indexed_spans_inner': [[4413, 4824]], 'text_spans_outer': [[21, 32]], 'text_spans_inner': [[21, 32]]}, '[NID] MedDRA PT': {'logical_column_id': 2, 'value': '10040882', 'original_spans_outer': [[103, 114]], 'original_spans_inner': [[103, 114]], 'indexed_spans_outer': [[4413, 4824]], 'indexed_spans_inner': [[4413, 4824]], 'text_spans_outer': [[21, 32]], 'text_spans_inner': [[21, 32]]}, '[PT] MedDRA LLT': {'logical_column_id': 3, 'value': 'Skin lesion', 'original_spans_outer': [[103, 114]], 'original_spans_inner': [[103, 114]], 'indexed_spans_outer': [[4413, 4824]], 'indexed_spans_inner': [[4413, 4824]], 'text_spans_outer': [[21, 32]], 'text_spans_inner': [[21, 32]]}, '[NID] MedDRA LLT': {'logical_column_id': 3, 'value': '10040882'}, 'Flag': {'logical_column_id': 4, 'value': ''}, 'text': {'value': 'There was an obvious skin lesion there and this gentleman has ...'}}, {'Certainty': {'logical_column_id': 0, 'value': ''}, '[PT] MedDRA PT': {'logical_column_id': 1, 'value': 'Skin lesion', 'original_spans_outer': [[214, 225]], 'original_spans_inner': [[214, 225]], 'indexed_spans_outer': [[8964, 9375]], 'indexed_spans_inner': [[8964, 9375]], 'text_spans_outer': [[34, 45]], 'text_spans_inner': [[34, 45]]}, '[NID] MedDRA PT': {'logical_column_id': 2, 'value': '10040882', 'original_spans_outer': [[214, 225]], 'original_spans_inner': [[214, 225]], 'indexed_spans_outer': [[8964, 9375]], 'indexed_spans_inner': [[8964, 9375]], 'text_spans_outer': [[34, 45]], 'text_spans_inner': [[34, 45]]}, '[PT] MedDRA LLT': {'logical_column_id': 3, 'value': 'Skin lesion', 'original_spans_outer': [[214, 225]], 'original_spans_inner': [[214, 225]], 'indexed_spans_outer': [[8964, 9375]], 'indexed_spans_inner': [[8964, 9375]], 'text_spans_outer': [[34, 45]], 'text_spans_inner': [[34, 45]]}, '[NID] MedDRA LLT': {'logical_column_id': 3, 'value': '10040882'}, 'Flag': {'logical_column_id': 4, 'value': ''}, 'text': {'value': '... punch biopsy of the worrisome skin lesion was obtained with a portion ...'}}, {'Certainty': {'logical_column_id': 0, 'value': ''}, '[PT] MedDRA PT': {'logical_column_id': 1, 'value': 'Squamous cell carcinoma', 'original_spans_outer': [[157, 180]], 'original_spans_inner': [[157, 180]], 'indexed_spans_outer': [[6627, 7530]], 'indexed_spans_inner': [[6627, 7530]], 'text_spans_outer': [[31, 54]], 'text_spans_inner': [[31, 54]]}, '[NID] MedDRA PT': {'logical_column_id': 2, 'value': '10041823', 'original_spans_outer': [[157, 180]], 'original_spans_inner': [[157, 180]], 'indexed_spans_outer': [[6627, 7530]], 'indexed_spans_inner': [[6627, 7530]], 'text_spans_outer': [[31, 54]], 'text_spans_inner': [[31, 54]]}, '[PT] MedDRA LLT': {'logical_column_id': 3, 'value': 'Squamous cell carcinoma', 'original_spans_outer': [[157, 180]], 'original_spans_inner': [[157, 180]], 'indexed_spans_outer': [[6627, 7530]], 'indexed_spans_inner': [[6627, 7530]], 'text_spans_outer': [[31, 54]], 'text_spans_inner': [[31, 54]]}, '[NID] MedDRA LLT': {'logical_column_id': 3, 'value': '10041823'}, 'Flag': {'logical_column_id': 4, 'value': ''}, 'text': {'value': '... gentleman has a history of squamous cell carcinoma .'}}]}

# %% [markdown]
# Now that we have got the JSON response from the MedDRA NLP API, we could convert the useful information associated with the keys into a pandas dataframe.

# %%
import pandas as pd

# initiate an empty dataframe
df = pd.DataFrame()
pd.set_option("display.max_rows", None, "display.max_columns", None, "display.width", 1000)

# Retrieve main results from the JSON response, please note this cell would fail if the request failed in the last step
results = body_json["results"]
for result_dict in results:
    df_dict = {}
    for key, value_dict in result_dict.items():
        df_dict[key] = value_dict['value']
    df = pd.concat([df, pd.DataFrame.from_records([{**df_dict}])], ignore_index=True)

# Check the dataframe
df
# Out:
#   Certainty           [PT] MedDRA PT [NID] MedDRA PT          [PT] MedDRA LLT [NID] MedDRA LLT Flag                                               text
# 0                        Skin lesion        10040882              Skin lesion         10040882       There was an obvious skin lesion there and thi...
# 1                        Skin lesion        10040882              Skin lesion         10040882       ... punch biopsy of the worrisome skin lesion ...
# 2            Squamous cell carcinoma        10041823  Squamous cell carcinoma         10041823       ... gentleman has a history of squamous cell c...

# %% [markdown]
# ### Example two: Make a request with a zip file as input

# %%
import os
import shutil
import zipfile

# Define input zip location
input_zip = os.path.join(os.path.dirname(os.getcwd()), "demo_docs/MedDRA_Codes/MedDRA_Codes_demo.zip")

# Define a directory to extract the input zip file into
input_folder = os.path.join(os.path.dirname(os.getcwd()), "demo_docs/MedDRA_Codes/MedDRA_Codes_demo")
if os.path.isdir(input_folder):
    shutil.rmtree(input_folder)
os.mkdir(input_folder)

# Extract files from the input zip into the folder
with zipfile.ZipFile(input_zip, "r") as zip_ref:
    zip_ref.extractall(input_folder)
print(f"Documents extracted to: {input_folder}")

# Make a request with all extracted files
print("Posting text files from the zip file...")
responses = []
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    with open(file_path, "r") as file:
        print(f"Posting {filename}...")
        response = requests.post(api_marketplace_url, headers=mkp_headers, files={'file': file})
        if response.status_code == 200:
            print("Success! Adding response to the full results!")
            responses.append(response.json())
        else:
            print(f"Error: {response}")
            exit()
print("All done!")
print(f"JSON responses are: {responses}")
# Out:
# Documents extracted to: C:\Users\Hui.Feng\Documents\Git\api-marketplace-demo\demo_docs/MedDRA_Codes/MedDRA_Codes_demo
# Posting text files from the zip file...
# Posting M1.txt...
# Success! Adding response to the full results!
# Posting M2.txt...
# Success! Adding response to the full results!
# All done!
# JSON responses are: [{'doc_id': 'M1.txt', 'results': [{'Certainty': {'logical_column_id': 0, 'value': ''}, '[PT] MedDRA PT': {'logical_column_id': 1, 'value': 'Hypothyroidism', 'original_spans_outer': [[1170, 1184]], 'original_spans_inner': [[1170, 1184]], 'indexed_spans_outer': [[48025, 48572]], 'indexed_spans_inner': [[48025, 48572]], 'text_spans_outer': [[56, 70]], 'text_spans_inner': [[56, 70]]}, '[NID] MedDRA PT': {'logical_column_id': 2, 'value': '10021114', 'original_spans_outer': [[1170, 1184]], 'original_spans_inner': [[1170, 1184]], 'indexed_spans_outer': [[48025, 48572]], 'indexed_spans_inner': [[48025, 48572]], 'text_spans_outer': [[56, 70]], 'text_spans_inner': [[56, 70]]}, '[PT] MedDRA LLT': {'logical_column_id': 3, 'value': 'Hypothyroidism', 'original_spans_outer': [[1170, 1184]], 'original_spans_inner': [[1170, 1184]], 'indexed_spans_outer': [[48025, 48572]], 'indexed_spans_inner': [[48025, 48572]], 'text_spans_outer': [[56, 70]], 'text_spans_inner': [[56, 70]]}, '[NID] MedDRA LLT': {'logical_column_id': 3, 'value': '10021114'}, 'Flag': {'logical_column_id': 4, 'value': 'Indication', 'original_spans_outer': [[1144, 1151]], 'original_spans_inner': [[1144, 1151]], 'indexed_spans_outer': [[46933, 47186]], 'indexed_spans_inner': [[46933, 47186]], 'text_spans_outer': [[30, 37]], 'text_spans_inner': [[30, 37]]}, 'text': {'value': '... is a consultation for the patient in regards to her hypothyroidism .'}}, {'Certainty': {'logical_column_id': 0, 'value': ''}, '[PT] MedDRA PT': {'logical_column_id': 1, 'value': 'Hypothyroidism', 'original_spans_outer': [[1170, 1184]], 'original_spans_inner': [[1170, 1184]], 'indexed_spans_outer': [[48025, 48572]], 'indexed_spans_inner': [[48025, 48572]], 'text_spans_outer': [[34, 48]], 'text_spans_inner': [[34, 48]]}, '[NID] MedDRA PT': {'logical_column_id': 2, 'value': '10021114', 'original_spans_outer': [[1170, 1184]], 'original_spans_inner': [[1170, 1184]], 'indexed_spans_outer': [[48025, 48572]], 'indexed_spans_inner': [[48025, 48572]], 'text_spans_outer': [[34, 48]], 'text_spans_inner': [[34, 48]]}, '[PT] MedDRA LLT': {'logical_column_id': 3, 'value': 'Hypothyroidism', 'original_spans_outer': [[1170, 1184]], 'original_spans_inner': [[1170, 1184]], 'indexed_spans_outer': [[48025, 48572]], 'indexed_spans_inner': [[48025, 48572]], 'text_spans_outer': [[34, 48]], 'text_spans_inner': [[34, 48]]}, '[NID] MedDRA LLT': {'logical_column_id': 3, 'value': '10021114'}, 'Flag': {'logical_column_id': 4, 'value': 'Indication', 'original_spans_outer': [[1166, 1169]], 'original_spans_inner': [[1166, 1169]], 'indexed_spans_outer': [[47857, 47942]], 'indexed_spans_inner': [[47857, 47942]], 'text_spans_outer': [[30, 33]], 'text_spans_inner': [[30, 33]]}, 'text': {'value': '... the patient in regards to her hypothyroidism .'}}, {'Certainty': {'logical_column_id': 0, 'value': ''}, '[PT] MedDRA PT': {'logical_column_id': 1, 'value': 'Skin lesion', 'original_spans_outer': [[90, 101]], 'original_spans_inner': [[90, 101]], 'indexed_spans_outer': [[3810, 4212]], 'indexed_spans_inner': [[3810, 4212]], 'text_spans_outer': [[44, 55]], 'text_spans_inner': [[44, 55]]}, '[NID] MedDRA PT': {'logical_column_id': 2, 'value': '10040882', 'original_spans_outer': [[90, 101]], 'original_spans_inner': [[90, 101]], 'indexed_spans_outer': [[3810, 4212]], 'indexed_spans_inner': [[3810, 4212]], 'text_spans_outer': [[44, 55]], 'text_spans_inner': [[44, 55]]}, '[PT] MedDRA LLT': {'logical_column_id': 3, 'value': 'Skin lesion', 'original_spans_outer': [[90, 101]], 'original_spans_inner': [[90, 101]], 'indexed_spans_outer': [[3810, 4212]], 'indexed_spans_inner': [[3810, 4212]], 'text_spans_outer': [[44, 55]], 'text_spans_inner': [[44, 55]]}, '[NID] MedDRA LLT': {'logical_column_id': 3, 'value': '10040882'}, 'Flag': {'logical_column_id': 4, 'value': ''}, 'text': {'value': '... 2017 PREOPERATIVE DIAGNOSIS : Worrisome skin lesion , left hand .'}}, {'Certainty': {'logical_column_id': 0, 'value': ''}, '[PT] MedDRA PT': {'logical_colu ...

# %% [markdown]
# Similar to Example one, you could convert the JSON output into a pandas dataframe.

# %%
import pandas as pd

# initiate an empty dataframe
df = pd.DataFrame()
pd.set_option("display.max_rows", None, "display.max_columns", None, "display.width", 1000)

# Retrieve main results from the JSON response, please note this cell would fail if the request failed in the last step
for body_json in responses:
    results = body_json["results"]
    for result_dict in results:
        df_dict = {}
        for key, value_dict in result_dict.items():
            df_dict[key] = value_dict['value']
        df_dict["Doc ID"] = body_json["doc_id"]
        df = pd.concat([df, pd.DataFrame.from_records([{**df_dict}])], ignore_index=True)

# Check the dataframe
df
# Out:
#        Certainty                               [PT] MedDRA PT [NID] MedDRA PT             [PT] MedDRA LLT [NID] MedDRA LLT           Flag                                               text  Doc ID
# 0                                              Hypothyroidism        10021114              Hypothyroidism         10021114     Indication  ... is a consultation for the patient in regar...  M1.txt
# 1                                              Hypothyroidism        10021114              Hypothyroidism         10021114     Indication  ... the patient in regards to her hypothyroidi...  M1.txt
# 2                                                 Skin lesion        10040882                 Skin lesion         10040882                 ... 2017 PREOPERATIVE DIAGNOSIS : Worrisome sk...  M1.txt
# 3                                                 Skin lesion        10040882                 Skin lesion         10040882                 POSTPROCEDURE DIAGNOSIS : Worrisome skin lesio...  M1.txt
# 4                                                 Skin lesion        10040882                 Skin lesion         10040882                 There was an obvious skin lesion there and thi...  M1.txt
# 5                                                 Skin lesion        10040882                 Skin lesion         10040882                 ... punch biopsy of the worrisome skin lesion ...  M1.txt
# 6                                     Squamous cell carcinoma        10041823     Squamous cell carcinoma         10041823                 ... gentleman has a history of squamous cell c...  M1.txt
# 7         Family                                  Thyroiditis        10043778                 Thyroiditis         10043778                 ... Graves disease , as well a sister with Has...  M2.txt
# 8   Hypothetical                             Weight decreased        10047895                                                              If she wanted to lose significant weight , I s...  M2.txt
# 9        Negated                               Abdominal pain        10000081              Abdominal pain         10000081                 ... some loosening stools , but denies abdomin...  M2.txt
# 10       Negated                                   Chest pain        10008479                  Chest pain         10008479                               Denies chest pain or palpitations .  M2.txt
# 11       Negated                              Hyperthyroidism        10020850             Hyperthyroidism         10020850                      ... to ensure that she is not hyperthyroid .  M2.txt
# 12       Negated                                 Palpitations        10033557                Palpitations         10033557                               Denies chest pain or palpitations .  M2.txt
# 13       Negated                           Periorbital oedema        10034545           Periorbital edema         10054541                            HEENT : She has no periorbital edema .  M2.txt
# 14   PastHistory                               Hypothyroidism        10021114              Hypothyroidism         10021114  Adverse Event  ... female with a history of I-131-induced hyp...  M2.txt
# 15   PastHistory                               Hypothyroidism        10021114              Hypothyroidism         10021114     Indication  ... : This is a 55-year-old female with a hist...  M2.txt
# 16   PastHistory                                       Oedema        10030095                       Edema         10014210     Indication  ... I-131-induced hypothyroidism years ago who...  M2.txt
# 17                Blood thyroid stimulating hormone decreased        10005832                                                  Indication  Her TSH is mildly suppressed , but her free T4...  M2.txt
# 18                      Chronic obstructive pulmonary disease        10009033                        COPD         10010952                 ... diabetes , Crohn disease , COPD , and disc...  M2.txt
# 19                      Chronic obstructive pulmonary disease        10009033                        COPD         10010952                 ... , hypertension , fibromyalgia , COPD , and...  M2.txt
# 20                                      Drug hypersensitivity        10013700                                                              Insulin as needed ALLERGIES : Include IV DYE ,...  M2.txt
# 21                                                    Fatigue        10016256                     Fatigue         10016256                 ... OF SYSTEMS : Positive for fatigue , sweats...  M2.txt
# 22                                               Fibromyalgia        10048439                Fibromyalgia         10048439                 ... also has a history of fibromyalgia , infla...  M2.txt
# 23                                               Fibromyalgia        10048439                Fibromyalgia         10048439                 ... with Crohn , hypertension , fibromyalgia ,...  M2.txt
# 24                                              Hyperhidrosis        10020642                    Sweating         10042661                 She has occasional sweats with no significant ...  M2.txt
# 25                                              Hyperhidrosis        10020642                    Sweating         10042661                 ... : Positive for fatigue , sweats , and weig...  M2.txt
# 26                                           Hypersensitivity        10020751                     Allergy         10001738     Indication  Insulin as needed ALLERGIES : Include IV DYE ,...  M2.txt
# 27                                               Hypertension        10020772                Hypertension         10020772     Indication  ... has been on Norvasc and lisinopril for yea...  M2.txt
# 28                                               Hypertension        10020772                Hypertension         10020772                 ... bowel disease with Crohn , hypertension , ...  M2.txt
# 29                                             Hypothyroidism        10021114              Hypothyroidism         10021114  Adverse Event  ... HISTORY : As above includes I-131-induced ...  M2.txt
# 30                                             Hypothyroidism        10021114              Hypothyroidism         10021114                        ... as well as history of hypothyroidism .  M2.txt
# 31                                             Hypothyroidism        10021114              Hypothyroidism         10021114                 Hypothyroidism is secondary to radioactive iod...  M2.txt
# 32                                 Inflammatory bowel disease        10021972  Inflammatory bowel disease         10021972  Adverse Event  ... HISTORY : As above includes I-131-induced ...  M2.txt
# 33                                 Inflammatory bowel disease        10021972  Inflammatory bowel disease         10021972                 ... a history of fibromyalgia , inflammatory b...  M2.txt
# 34                                                    Obesity        10029883                     Obesity         10029883                            ... GENERAL : She is an obese female .  M2.txt
# 35                                                     Oedema        10030095                       Edema         10014210     Indication                    EXTREMITIES : Showed 1+ edema .  M2.txt
# 36                                                     Oedema        10030095                       Edema         10014210     Indication  ... : This is a 55-year-old female with weight...  M2.txt
# 37                                                     Oedema        10030095                       Edema         10014210                 ... girth as well as increasing edema in her l...  M2.txt
# 38                                                   Swelling        10042674                    Swelling         10042674                 ... increasing girth and increasing leg swelli...  M2.txt
# 39                                           Thyroid disorder        10043709            Thyroid disorder         10043709                    ... disc disease as well as thyroid disorder .  M2.txt
# 40                                   Type 2 diabetes mellitus        10067585                                                              ... , inflammatory bowel disease , type 2 diab...  M2.txt
# 41                              Waist circumference increased        10064863                                                              She has noticed increasing abdominal girth as ...  M2.txt
# 42                              Waist circumference increased        10064863   Increased abdominal girth         10066440                 She has noticed increasing abdominal girth as ...  M2.txt
# 43                                           Weight increased        10047899                 Weight gain         10047896     Indication  ... : This is a 55-year-old female with weight...  M2.txt
# 44                                           Weight increased        10047899                 Weight gain         10047896     Indication  ... : This is a 55-year-old female with weight...  M2.txt
# 45                                           Weight increased        10047899                 Weight gain         10047896     Indication  ... is mildly suppressed , but her free T4 is ...  M2.txt
# 46                                           Weight increased        10047899                 Weight gain         10047896     Indication  ... T4 is normal and with her weight gain I wi...  M2.txt
# 47                                           Weight increased        10047899                                               Adverse Event  ... female with a history of I-131-induced hyp...  M2.txt
# 48                                           Weight increased        10047899                                                  Indication  ... I-131-induced hypothyroidism years ago who...  M2.txt
# 49                                           Weight increased        10047899                                                  Indication  ... is mildly suppressed , but her free T4 is ...  M2.txt
# 50                                           Weight increased        10047899                                                  Indication  ... T4 is normal and with her weight gain I wi...  M2.txt
# 51                                           Weight increased        10047899                                                                    ... few weeks with a 25-pound weight gain .  M2.txt
# 52                                           Weight increased        10047899                                                              ... fatigue , sweats , and weight gain of 20 p...  M2.txt
# 53                                           Weight increased        10047899                 Weight gain         10047896                       ... few weeks with a 25-pound weight gain .  M2.txt
# 54                                           Weight increased        10047899                 Weight gain         10047896                 ... fatigue , sweats , and weight gain of 20 p...  M2.txt

# %% [markdown]
# That's it! Hope you find this tutorial useful! Bye!
