# %% [markdown]
# # IQVIA NLP - Healthcare Concepts
#
# ## API Description
# NLP with the ability to recognize key Healthcare concepts, whilst recognizing context and patterns in data such as drugs, disease, smoking categorization, which are relevant to healthcare organizations.
#
# ## Accessing the API
# In order to consume this API, you will first need to Request access to the Healthcare Concepts API via this link:
# https://api-marketplace.work.iqvia.com/s/communityapi/a085w00000zhFVKAA2/api-marketplaceiqvianlphealthcareconceptspreview
#
# Please refer to "API Documentation" to learn more about accessing and using the API.
#
# ## Notebook Description
# This notebook is designed to show users an example of using the Healthcare Concepts NLP API to extract features related to healthcare concepts such as populations and medications found in medical records.
#
# ### Authorization
# The instructions for getting your credentials and the API endpoint URL can be found under the section "Get Started" and "How to use the API" following this link: https://api-marketplace.work.iqvia.com/s/communityapi/a085w00000zhFVKAA2/api-marketplaceiqvianlphealthcareconceptspreview

# %%
import getpass
import requests

# In this demo scenario, URL for US based customers
# api_marketplace_url = 'https://vt.us-rds.solutions.iqvia.com/multi/api/v1/multi/'
# In this demo scenario, URL for EU based customers
api_marketplace_url = 'https://vt.eu-apim.solutions.iqvia.com/eu/multi/api/v1/multi/'

mkp_user = input("Marketplace clientId: ")
mkp_password = getpass.getpass("Marketplace clientSecret: ")
mkp_headers = {'clientId': mkp_user, 'clientSecret': mkp_password}

# Check credentials by making a dummy request
print("Checking your credentials, please wait...")
response = requests.post(api_marketplace_url, headers=mkp_headers, files={'file': "test"})

if response.status_code == 200:
    print("Congratulations! Your credentials are accepted!")
else:
    raise Exception(f"Error: {response}")
# Out:
# Marketplace clientId: 195e71bb99f0477eb16bb01ae36e314a
# Marketplace clientSecret: ········
# Checking your credentials, please wait...
# Congratulations! Your credentials are accepted!

# %% [markdown]
# ### Example one: Make a request with text string as input
# Healthcare Concepts NLP API expects the String as Request Data Type. This example shows how to make a request to the API with text strings as input.

# %%
import requests

# Define input text
input_text = "HISTORY OF PRESENT ILLNESS:  This 60-year-old white male is referred to us by his medical physician with a complaint of recent finding of a both pancreatic lesion and lesions with left adrenal gland.  The patient's history dates back to at the end of the January of this past year when he began experiencing symptoms consistent with difficulty almost like a suffocating feeling whenever he would lie flat on his back.  He noticed whenever he would recline backwards, he would begin this feeling and it is so bad now that he can barely recline, very little before he has this feeling. He does have a history of frequent urination.  Has been followed by urologist for this.  There is no family history of pancreatic cancer.  There is a history of gallstone pancreatitis in the patient's sister. MEDICATIONS:  Include glipizide 5 mg b.i.d., metformin 500 mg b.i.d., Atacand 16 mg daily, metoprolol 25 mg b.i.d., Lipitor 10 mg daily, pantoprazole 40 mg daily, Flomax 0.4 mg daily, Detrol 4 mg daily, Zyrtec 10 mg daily, Advair Diskus 100/50 mcg one puff b.i.d., and fluticasone spray 50 mcg two sprays daily. PAST SURGICAL HISTORY:  He has not had any previous surgery."

# Make a request
print("Posting text strings...")
response = requests.post(api_marketplace_url, headers=mkp_headers, files={'file': input_text})

# Check the response
if response.status_code == 200:
    print("Success!")
    body_json = response.json()
    print(f"Raw JSON response from the API is: {body_json}")
else:
    raise Exception(f"Error: {response}")
# Out:
# Posting text strings...
# Success!
# Raw JSON response from the API is: {'doc_id': 'file', 'results': [{'concept': {'logical_column_id': 0, 'value': '0.4', 'original_spans_outer': [[963, 966]], 'original_spans_inner': [[963, 966]], 'indexed_spans_outer': [[39683, 39766]], 'indexed_spans_inner': [[39683, 39766]], 'text_spans_outer': [[25, 28]], 'text_spans_inner': [[25, 28]]}, 'preferred_term': {'logical_column_id': 0, 'value': '0.4'}, 'ontology': {'logical_column_id': 0, 'value': 'numerics'}, 'node_id': {'logical_column_id': 0, 'value': 'decimals:0.4'}, 'category': {'logical_column_id': 1, 'value': 'MeasurementValue'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': '... 40 mg daily , Flomax 0.4 mg daily , Detrol 4 ...'}}, {'concept': {'logical_column_id': 0, 'value': '0.4 mg daily', 'original_spans_outer': [[963, 975]], 'original_spans_inner': [[963, 975]], 'indexed_spans_outer': [[39683, 40135]], 'indexed_spans_inner': [[39683, 40135]], 'text_spans_outer': [[25, 37]], 'text_spans_inner': [[25, 37]]}, 'preferred_term': {'logical_column_id': 0, 'value': '0.4 mg every 1d'}, 'ontology': {'logical_column_id': 0, 'value': 'measurement'}, 'node_id': {'logical_column_id': 0, 'value': 'dosage-g:0.4 mg every 1d'}, 'category': {'logical_column_id': 1, 'value': 'Dosage'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': '... 40 mg daily , Flomax 0.4 mg daily , Detrol 4 mg daily ...'}}, {'concept': {'logical_column_id': 0, 'value': '4', 'original_spans_outer': [[984, 985]], 'original_spans_inner': [[984, 985]], 'indexed_spans_outer': [[40544, 40545]], 'indexed_spans_inner': [[40544, 40545]], 'text_spans_outer': [[26, 27]], 'text_spans_inner': [[26, 27]]}, 'preferred_term': {'logical_column_id': 0, 'value': '4'}, 'ontology': {'logical_column_id': 0, 'value': 'numerics'}, 'node_id': {'logical_column_id': 0, 'value': 'integers:4'}, 'category': {'logical_column_id': 1, 'value': 'MeasurementValue'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': '... 0.4 mg daily , Detrol 4 mg daily , Zyrtec 10 ...'}}, {'concept': {'logical_column_id': 0, 'value': '4 mg daily', 'original_spans_outer': [[984, 994]], 'original_spans_inner': [[984, 994]], 'indexed_spans_outer': [[40544, 40914]], 'indexed_spans_inner': [[40544, 40914]], 'text_spans_outer': [[26, 36]], 'text_spans_inner': [[26, 36]]}, 'preferred_term': {'logical_column_id': 0, 'value': '4 mg every 1d'}, 'ontology': {'logical_column_id': 0, 'value': 'measurement'}, 'node_id': {'logical_column_id': 0, 'value': 'dosage-g:4 mg every 1d'}, 'category': {'logical_column_id': 1, 'value': 'Dosage'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': '... 0.4 mg daily , Detrol 4 mg daily , Zyrtec 10 mg daily ...'}}, {'concept': {'logical_column_id': 0, 'value': '5', 'original_spans_outer': [[825, 826]], 'original_spans_inner': [[825, 826]], 'indexed_spans_outer': [[34025, 34026]], 'indexed_spans_inner': [[34025, 34026]], 'text_spans_outer': [[32, 33]], 'text_spans_inner': [[32, 33]]}, 'preferred_term': {'logical_column_id': 0, 'value': '5'}, 'ontology': {'logical_column_id': 0, 'value': 'numerics'}, 'node_id': {'logical_column_id': 0, 'value': 'integers:5'}, 'category': {'logical_column_id': 1, 'value': 'MeasurementValue'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': 'MEDICATIONS : Include glipizide 5 mg b.i.d. , metformin 500 ...'}}, {'concept': {'logical_column_id': 0, 'value': '5 mg b.i.d.', 'original_spans_outer': [[825, 836]], 'original_spans_inner': [[825, 836]], 'indexed_spans_outer': [[34025, 34436]], 'indexed_spans_inner': [[34025, 34436]], 'text_spans_outer': [[32, 43]], 'text_spans_inner': [[32, 43]]}, 'preferred_term': {'logical_column_id': 0, 'value': '5 mg every 12h'}, 'ontology': {'logical_column_id': 0, 'value': 'measurement'}, 'node_id': {'logical_column_id': 0, 'value': 'dosage-g:5 mg every 12h'}, 'category': {'logical_column_id': 1, 'value': 'Dosage'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'va ...

# %% [markdown]
# Now that we have got the JSON response from the Healthcare Concepts NLP API, we could convert the useful information associated with the keys into a pandas dataframe.

# %%
import pandas as pd

# initiate an empty dataframe
df = pd.DataFrame()
pd.set_option("display.max_rows", None, "display.max_columns", None, "display.width", 1000)

# Retrieve main results from the JSON response, please note this cell would fail if the request failed in the last step
results = body_json["results"]
for result_dict in results:
    df_dict = {}
    for key, value_dict in result_dict.items():
        df_dict[key] = value_dict['value']
    df = pd.concat([df, pd.DataFrame.from_records([{**df_dict}])], ignore_index=True)

# Check the dataframe
df
# Out:
#                          concept                                    preferred_term      ontology                              node_id                category       certainty                                               text
# 0                            0.4                                               0.4      numerics                         decimals:0.4        MeasurementValue                  ... 40 mg daily , Flomax 0.4 mg daily , Detrol...
# 1                   0.4 mg daily                                   0.4 mg every 1d   measurement             dosage-g:0.4 mg every 1d                  Dosage                  ... 40 mg daily , Flomax 0.4 mg daily , Detrol...
# 2                              4                                                 4      numerics                           integers:4        MeasurementValue                  ... 0.4 mg daily , Detrol 4 mg daily , Zyrtec ...
# 3                     4 mg daily                                     4 mg every 1d   measurement               dosage-g:4 mg every 1d                  Dosage                  ... 0.4 mg daily , Detrol 4 mg daily , Zyrtec ...
# 4                              5                                                 5      numerics                           integers:5        MeasurementValue                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 5                    5 mg b.i.d.                                    5 mg every 12h   measurement              dosage-g:5 mg every 12h                  Dosage                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 6                             10                                                10      numerics                          integers:10        MeasurementValue                  ... 25 mg b.i.d. , Lipitor 10 mg daily , panto...
# 7                             10                                                10      numerics                          integers:10        MeasurementValue                  ... 4 mg daily , Zyrtec 10 mg daily , Advair D...
# 8                    10 mg daily                                    10 mg every 1d   measurement              dosage-g:10 mg every 1d                  Dosage                  ... 25 mg b.i.d. , Lipitor 10 mg daily , panto...
# 9                    10 mg daily                                    10 mg every 1d   measurement              dosage-g:10 mg every 1d                  Dosage                  ... 4 mg daily , Zyrtec 10 mg daily , Advair D...
# 10                            16                                                16      numerics                          integers:16        MeasurementValue                  ... 500 mg b.i.d. , Atacand 16 mg daily , meto...
# 11                   16 mg daily                                    16 mg every 1d   measurement              dosage-g:16 mg every 1d                  Dosage                  ... 500 mg b.i.d. , Atacand 16 mg daily , meto...
# 12                            25                                                25      numerics                          integers:25        MeasurementValue                  ... 16 mg daily , metoprolol 25 mg b.i.d. , Li...
# 13                  25 mg b.i.d.                                   25 mg every 12h   measurement             dosage-g:25 mg every 12h                  Dosage                  ... 16 mg daily , metoprolol 25 mg b.i.d. , Li...
# 14                            40                                                40      numerics                          integers:40        MeasurementValue                  ... 10 mg daily , pantoprazole 40 mg daily , F...
# 15                   40 mg daily                                    40 mg every 1d   measurement              dosage-g:40 mg every 1d                  Dosage                  ... 10 mg daily , pantoprazole 40 mg daily , F...
# 16                            50                                                50      numerics                          integers:50        MeasurementValue                  ... b.i.d. , and fluticasone spray 50 mcg two ...
# 17                        50 mcg                                           0.05 mg   measurement                            g:0.05 mg                  Dosage                  ... , Advair Diskus 100 / 50 mcg one puff b.i....
# 18                        50 mcg                                           0.05 mg   measurement                            g:0.05 mg                  Dosage                  ... b.i.d. , and fluticasone spray 50 mcg two ...
# 19                   60-year-old                                            Adults           age                              age:60y                     Age                  ... OF PRESENT ILLNESS : This 60-year-old whit...
# 20                      100 / 50                            Numerics /, : Numeri..        phrase               Numerics /, : Numeri..        MeasurementValue                  ... mg daily , Advair Diskus 100 / 50 mcg one ...
# 21                           500                                               500      numerics                         integers:500        MeasurementValue                  ... 5 mg b.i.d. , metformin 500 mg b.i.d. , At...
# 22                 500 mg b.i.d.                                  500 mg every 12h   measurement            dosage-g:500 mg every 12h                  Dosage                  ... 5 mg b.i.d. , metformin 500 mg b.i.d. , At...
# 23                        Advair               fluticasone propionate + salmeterol           nci  salmeterol_+_fluticasone_propionate          MedicationName                  ... Zyrtec 10 mg daily , Advair Diskus 100 / 5...
# 24                 Advair Diskus           Fluticasone-Salmeterol Drug Combination           nlm                           D000068297          MedicationName                  ... Zyrtec 10 mg daily , Advair Diskus 100 / 5...
# 25          any previous surgery                                           Surgery        meddra                             10042609  TreatmentAndProcedures         Negated  PAST SURGICAL HISTORY : He has not had any pre...
# 26          any previous surgery                                           Surgery        meddra                             10042609  TreatmentAndProcedures  NegatedHistory  PAST SURGICAL HISTORY : He has not had any pre...
# 27                       Atacand             Agent Affecting Cardiovascular System           nci                               C78274         MedicationClass                  ... metformin 500 mg b.i.d. , Atacand 16 mg da...
# 28                       Atacand                             Candesartan Cilexetil           nci                               C28903          MedicationName                  ... metformin 500 mg b.i.d. , Atacand 16 mg da...
# 29                        b.i.d.                                               12h    durAndFreq                       dosageFreq:12h               Frequency                  ... : Include glipizide 5 mg b.i.d. , metformi...
# 30                        b.i.d.                                               12h    durAndFreq                       dosageFreq:12h               Frequency                  ... b.i.d. , metformin 500 mg b.i.d. , Atacand...
# 31                        b.i.d.                                               12h    durAndFreq                       dosageFreq:12h               Frequency                  ... daily , metoprolol 25 mg b.i.d. , Lipitor ...
# 32                        b.i.d.                                               12h    durAndFreq                       dosageFreq:12h               Frequency                  ... / 50 mcg one puff b.i.d. , and fluticasone...
# 33                          back                                              Back           nci                               C13062           BodyStructure                                   ... would lie flat on his back .
# 34                          back                                              Back           nlm                              D001415           BodyStructure                                   ... would lie flat on his back .
# 35                          back       Structure of back of trunk (body structure)        snomed                             77568009           BodyStructure                                   ... would lie flat on his back .
# 36                     complaint                                         Complaint           nci                              C176714        DiseaseOrSymptom                  ... his medical physician with a complaint of ...
# 37                     complaint                               Complaint (finding)        snomed                            409586006        DiseaseOrSymptom                  ... his medical physician with a complaint of ...
# 38                         daily                                                1d    durAndFreq                        dosageFreq:1d               Frequency                  ... b.i.d. , Atacand 16 mg daily , metoprolol ...
# 39                         daily                                                1d    durAndFreq                        dosageFreq:1d               Frequency                  ... b.i.d. , Lipitor 10 mg daily , pantoprazol...
# 40                         daily                                                1d    durAndFreq                        dosageFreq:1d               Frequency                  ... daily , pantoprazole 40 mg daily , Flomax ...
# 41                         daily                                                1d    durAndFreq                        dosageFreq:1d               Frequency                  ... daily , Flomax 0.4 mg daily , Detrol 4 mg ...
# 42                         daily                                                1d    durAndFreq                        dosageFreq:1d               Frequency                  ... daily , Detrol 4 mg daily , Zyrtec 10 mg d...
# 43                         daily                                                1d    durAndFreq                        dosageFreq:1d               Frequency                  ... daily , Zyrtec 10 mg daily , Advair Diskus...
# 44                         daily                                                1d    durAndFreq                        dosageFreq:1d               Frequency                                ... spray 50 mcg two sprays daily .
# 45                        Detrol                    Agent Affecting Nervous System           nci                               C78272         MedicationClass                  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 46                        Detrol                                       Tolterodine           nci                               C62083          MedicationName                  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 47                        Detrol                              Tolterodine Tartrate           nci                               C29504          MedicationName                  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 48                        Detrol                              Tolterodine Tartrate           nlm                           D000068737          MedicationName                  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 49                       finding                                           Finding           nci                                C3367        DiseaseOrSymptom                  ... with a complaint of recent finding of a bo...
# 50                        Flomax                    Agent Affecting Nervous System           nci                               C78272         MedicationClass                  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 51                        Flomax                                        Tamsulosin           nci                               C75055          MedicationName                  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 52                        Flomax                                        Tamsulosin           nlm                           D000077409          MedicationName                  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 53                        Flomax                          Tamsulosin Hydrochloride           nci                               C29486          MedicationName                  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 54                   fluticasone                                       Fluticasone           nci                               C61767          MedicationName                  ... one puff b.i.d. , and fluticasone spray 50...
# 55                   fluticasone                                       Fluticasone           nlm                           D000068298          MedicationName                  ... one puff b.i.d. , and fluticasone spray 50...
# 56                   fluticasone                           Fluticasone (substance)        snomed                            397192001          MedicationName                  ... one puff b.i.d. , and fluticasone spray 50...
# 57                   fluticasone                             Hormone Therapy Agent           nci                              C147908         MedicationClass                  ... one puff b.i.d. , and fluticasone spray 50...
# 58                   fluticasone                           Immunotherapeutic Agent           nci                                 C308         MedicationClass                  ... one puff b.i.d. , and fluticasone spray 50...
# 59                     gallstone                                    Cholelithiasis        meddra                             10008629        DiseaseOrSymptom          Family  There is a history of gallstone pancreatitis i...
# 60                     gallstone                                    Cholelithiasis      nlm_plus                              D002769        DiseaseOrSymptom          Family  There is a history of gallstone pancreatitis i...
# 61                     gallstone                                        Gallstones      nlm_plus                              D042882        DiseaseOrSymptom          Family  There is a history of gallstone pancreatitis i...
# 62        gallstone pancreatitis                 Gallstone pancreatitis (disorder)        snomed                             95563007        DiseaseOrSymptom          Family  There is a history of gallstone pancreatitis i...
# 63                     glipizide    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 64                     glipizide                                         Glipizide           nci                               C29074          MedicationName                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 65                     glipizide                                         Glipizide           nlm                              D005913          MedicationName                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 66                     glipizide                             Glipizide (substance)        snomed                            387143009          MedicationName                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 67                       ILLNESS                                           Illness        meddra                             10080284        DiseaseOrSymptom                  HISTORY OF PRESENT ILLNESS : This 60-year-old ...
# 68                       ILLNESS                                 Illness (finding)        snomed                             39104002        DiseaseOrSymptom                  HISTORY OF PRESENT ILLNESS : This 60-year-old ...
# 69     January of this past year                         January of this past year          date    PastMo: January of this past year                    Date                  ... at the end of the January of this past yea...
# 70            left adrenal gland                                    Adrenal Glands           nlm                              D000311           BodyStructure                  ... pancreatic lesion and lesions with left ad...
# 71            left adrenal gland                                Left Adrenal Gland           nci                               C49322           BodyStructure                  ... pancreatic lesion and lesions with left ad...
# 72            left adrenal gland  Structure of left adrenal gland (body structure)        snomed                             12003004           BodyStructure                  ... pancreatic lesion and lesions with left ad...
# 73                        lesion                                            Lesion           nci                                C3824        DiseaseOrSymptom                  ... finding of a both pancreatic lesion and le...
# 74                        lesion                               Wounds and Injuries      nlm_plus                              D014947        DiseaseOrSymptom                  ... finding of a both pancreatic lesion and le...
# 75                       lesions                               Wounds and Injuries      nlm_plus                              D014947        DiseaseOrSymptom                  ... a both pancreatic lesion and lesions with ...
# 76                       Lipitor    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 77                       Lipitor                                      Atorvastatin           nci                               C61527          MedicationName                  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 78                       Lipitor                                      Atorvastatin           nlm                           D000069059          MedicationName                  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 79                       Lipitor                              Atorvastatin Calcium           nci                               C28837          MedicationName                  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 80                       Lipitor                                  Enzyme Inhibitor           nci                                 C471         MedicationClass                  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 81                          male                                              Male                                                                     Gender                  ... ILLNESS : This 60-year-old white male is r...
# 82                     metformin    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 83                     metformin                             Chemopreventive Agent           nci                                C1892         MedicationClass                  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 84                     metformin                                         Metformin           nci                               C61612          MedicationName                  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 85                     metformin                                         Metformin           nlm                              D008687          MedicationName                  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 86                     metformin                             Metformin (substance)        snomed                            372567009          MedicationName                  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 87                    metoprolol                    Agent Affecting Nervous System           nci                               C78272         MedicationClass                  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 88                    metoprolol                                        Metoprolol           nci                               C61845          MedicationName                  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 89                    metoprolol                                        Metoprolol           nlm                              D008790          MedicationName                  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 90                    metoprolol                            Metoprolol (substance)        snomed                            372826007          MedicationName                  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 91                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 92                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg b.i.d. , metformin 500 mg b.i.d. , Atac...
# 93                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg b.i.d. , Atacand 16 mg daily , metoprol...
# 94                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg daily , metoprolol 25 mg b.i.d. , Lipit...
# 95                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg b.i.d. , Lipitor 10 mg daily , pantopra...
# 96                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg daily , pantoprazole 40 mg daily , Flom...
# 97                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg daily , Flomax 0.4 mg daily , Detrol 4 ...
# 98                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg daily , Detrol 4 mg daily , Zyrtec 10 m...
# 99                            mg                                         milligram          ucum                                   mg         MeasurementUnit                  ... mg daily , Zyrtec 10 mg daily , Advair Dis...
# 100            pancreatic cancer                              Pancreatic Carcinoma           nci                                C3850        DiseaseOrSymptom         Negated  There is no family history of pancreatic cancer .
# 101            pancreatic cancer                              Pancreatic Carcinoma           nci                                C3850        DiseaseOrSymptom   NegatedFamily  There is no family history of pancreatic cancer .
# 102            pancreatic cancer                              Pancreatic Carcinoma           nci                                C3850        DiseaseOrSymptom  NegatedHistory  There is no family history of pancreatic cancer .
# 103            pancreatic cancer                              Pancreatic carcinoma        meddra                             10033609        DiseaseOrSymptom         Negated  There is no family history of pancreatic cancer .
# 104            pancreatic cancer                              Pancreatic carcinoma        meddra                             10033609        DiseaseOrSymptom   NegatedFamily  There is no family history of pancreatic cancer .
# 105            pancreatic cancer                              Pancreatic carcinoma        meddra                             10033609        DiseaseOrSymptom  NegatedHistory  There is no family history of pancreatic cancer .
# 106            pancreatic cancer                              Pancreatic Neoplasms      nlm_plus                              D010190        DiseaseOrSymptom         Negated  There is no family history of pancreatic cancer .
# 107            pancreatic cancer                              Pancreatic Neoplasms      nlm_plus                              D010190        DiseaseOrSymptom   NegatedFamily  There is no family history of pancreatic cancer .
# 108            pancreatic cancer                              Pancreatic Neoplasms      nlm_plus                              D010190        DiseaseOrSymptom  NegatedHistory  There is no family history of pancreatic cancer .
# 109            pancreatic lesion                  Lesion (morphologic abnormality)        snomed                             52988006           BodyStructure                  ... recent finding of a both pancreatic lesion...
# 110                 pancreatitis                                      Pancreatitis        meddra                             10033645        DiseaseOrSymptom          Family  ... is a history of gallstone pancreatitis in ...
# 111                 pancreatitis                                      Pancreatitis           nci                                C3306        DiseaseOrSymptom          Family  ... is a history of gallstone pancreatitis in ...
# 112                 pancreatitis                                      Pancreatitis      nlm_plus                              D010195        DiseaseOrSymptom          Family  ... is a history of gallstone pancreatitis in ...
# 113                 pancreatitis                           Pancreatitis, CTCAE 3.0           nci                               C56602        DiseaseOrSymptom          Family  ... is a history of gallstone pancreatitis in ...
# 114                 pancreatitis                           Pancreatitis, CTCAE 5.0           nci                              C146789        DiseaseOrSymptom          Family  ... is a history of gallstone pancreatitis in ...
# 115                 pantoprazole    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 116                 pantoprazole                                      Pantoprazole           nci                               C29346          MedicationName                  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 117                 pantoprazole                                      Pantoprazole           nlm                           D000077402          MedicationName                  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 118                 pantoprazole                          Pantoprazole (substance)        snomed                            395821003          MedicationName                  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 119                    physician                            Physician (occupation)        snomed                            309343006    HealthcareProfession                  ... to us by his medical physician with a comp...
# 120                    physician                                        Physicians           nlm                              D010820    HealthcareProfession                  ... to us by his medical physician with a comp...
# 121                  suffocating                                          Asphyxia      nlm_plus                              D001237        DiseaseOrSymptom                  ... with difficulty almost like a suffocating ...
# 122                  suffocating                             Suffocating (finding)        snomed                            271877004        DiseaseOrSymptom                  ... with difficulty almost like a suffocating ...
# 123          suffocating feeling                               Suffocation feeling        meddra                             10042444        DiseaseOrSymptom                  ... with difficulty almost like a suffocating ...
# 124                     symptoms                                           Symptom           nci                                C4876        DiseaseOrSymptom                  ... year when he began experiencing symptoms c...
# 125                  the January                                                01          date                               Mo: 01                    Date                  ... to at the end of the January of this past ...
# 126         the patient's sister                                            Sister  Linguamatics                               sister          FamilyRelation                  ... history of gallstone pancreatitis in the p...
# 127  This 60-year-old white male                                             White  Linguamatics                                White         PopulationGroup                  HISTORY OF PRESENT ILLNESS : This 60-year-old ...
# 128                    urination                                         Urination           nlm                              D014554        DiseaseOrSymptom                         ... have a history of frequent urination .
# 129                    urologist                            Urologist (occupation)        snomed                             24590004    HealthcareProfession                          Has been followed by urologist for this .
# 130                    urologist                                        Urologists           nlm                           D000072178    HealthcareProfession                          Has been followed by urologist for this .
# 131                       Zyrtec                                        Cetirizine           nci                                C1042          MedicationName                  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...
# 132                       Zyrtec                                        Cetirizine           nlm                              D017332          MedicationName                  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...
# 133                       Zyrtec                          Cetirizine Hydrochloride           nci                               C28920          MedicationName                  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...
# 134                       Zyrtec                           Immunotherapeutic Agent           nci                                 C308         MedicationClass                  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...

# %% [markdown]
# ### Example two: Make a request with a zip file as input

# %%
import os
import shutil
import zipfile

# Define input zip location
input_zip = os.path.join(os.getcwd(), "demo_docs/HealthcareConcepts/HealthcareConcepts_demo.zip")

# Define a directory to extract the input zip file into
input_folder = os.path.join(os.getcwd(), "demo_docs/HealthcareConcepts/HealthcareConcepts_demo")
if os.path.isdir(input_folder):
    shutil.rmtree(input_folder)
os.mkdir(input_folder)

# Extract files from the input zip into the folder
with zipfile.ZipFile(input_zip, "r") as zip_ref:
    zip_ref.extractall(input_folder)
print(f"Documents extracted to: {input_folder}")

# Make a request with all extracted files
print("Posting text files from the zip file...")
responses = []
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    with open(file_path, "r") as file:
        print(f"Posting {filename}...")
        response = requests.post(api_marketplace_url, headers=mkp_headers, files={'file': file})
        if response.status_code == 200:
            print("Success! Adding response to the full results!")
            responses.append(response.json())
        else:
            print(f"Error: {response}")
            exit()
print("All done!")
print(f"JSON responses are: {responses}")
# Out:
# Documents extracted to: C:\Users\Hui.Feng\Documents\Git\api-marketplace-demo\demo_docs/HealthcareConcepts/HealthcareConcepts_demo
# Posting text files from the zip file...
# Posting M1.txt...
# Success! Adding response to the full results!
# Posting M2.txt...
# Success! Adding response to the full results!
# All done!
# JSON responses are: [{'doc_id': 'M1.txt', 'results': [{'concept': {'logical_column_id': 0, 'value': '5-0 nylon suture', 'original_spans_outer': [[887, 903]], 'original_spans_inner': [[897, 903]], 'indexed_spans_outer': [[36300, 36916]], 'indexed_spans_inner': [[36710, 36916]], 'text_spans_outer': [[30, 46]], 'text_spans_inner': [[40, 46]]}, 'preferred_term': {'logical_column_id': 0, 'value': 'Sutures'}, 'ontology': {'logical_column_id': 0, 'value': 'nlm'}, 'node_id': {'logical_column_id': 0, 'value': 'D013537'}, 'category': {'logical_column_id': 1, 'value': 'MedicalEquipment'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': '... the area were closed with 5-0 nylon suture .'}}, {'concept': {'logical_column_id': 0, 'value': 'a consultation', 'original_spans_outer': [[1121, 1135]], 'original_spans_inner': [[1123, 1135]], 'indexed_spans_outer': [[45967, 46514]], 'indexed_spans_inner': [[46051, 46514]], 'text_spans_outer': [[8, 22]], 'text_spans_inner': [[10, 22]]}, 'preferred_term': {'logical_column_id': 0, 'value': 'Consultation (procedure)'}, 'ontology': {'logical_column_id': 0, 'value': 'snomed'}, 'node_id': {'logical_column_id': 0, 'value': '11429006'}, 'category': {'logical_column_id': 1, 'value': 'TreatmentAndProcedures'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': 'This is a consultation for the patient in regards ...'}}, {'concept': {'logical_column_id': 0, 'value': 'A sterile dressing', 'original_spans_outer': [[959, 977]], 'original_spans_inner': [[969, 977]], 'indexed_spans_outer': [[39252, 39950]], 'indexed_spans_inner': [[39662, 39950]], 'text_spans_outer': [[0, 18]], 'text_spans_inner': [[10, 18]]}, 'preferred_term': {'logical_column_id': 0, 'value': 'Application of dressing (procedure)'}, 'ontology': {'logical_column_id': 0, 'value': 'snomed'}, 'node_id': {'logical_column_id': 0, 'value': '3895009'}, 'category': {'logical_column_id': 1, 'value': 'TreatmentAndProcedures'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': 'A sterile dressing was applied .'}}, {'concept': {'logical_column_id': 0, 'value': 'A sterile dressing', 'original_spans_outer': [[959, 977]], 'original_spans_inner': [[969, 977]], 'indexed_spans_outer': [[39252, 39950]], 'indexed_spans_inner': [[39662, 39950]], 'text_spans_outer': [[0, 18]], 'text_spans_inner': [[10, 18]]}, 'preferred_term': {'logical_column_id': 0, 'value': 'Bandages'}, 'ontology': {'logical_column_id': 0, 'value': 'nlm'}, 'node_id': {'logical_column_id': 0, 'value': 'D001458'}, 'category': {'logical_column_id': 1, 'value': 'MedicalEquipment'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': 'A sterile dressing was applied .'}}, {'concept': {'logical_column_id': 0, 'value': 'A sterile dressing', 'original_spans_outer': [[959, 977]], 'original_spans_inner': [[961, 968]], 'indexed_spans_outer': [[39252, 39950]], 'indexed_spans_inner': [[39334, 39941]], 'text_spans_outer': [[0, 18]], 'text_spans_inner': [[2, 9]]}, 'preferred_term': {'logical_column_id': 0, 'value': 'Sterilisation'}, 'ontology': {'logical_column_id': 0, 'value': 'meddra'}, 'node_id': {'logical_column_id': 0, 'value': '10062116'}, 'category': {'logical_column_id': 1, 'value': 'TreatmentAndProcedures'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': 'A sterile dressing was applied .'}}, {'concept': {'logical_column_id': 0, 'value': 'an obvious skin lesion', 'original_spans_outer': [[480, 502]], 'original_spans_inner': [[491, 495]], 'indexed_spans_outer': [[19707, 20569]], 'indexed_spans_inner': [[20158, 20562]], 'text_spans_outer': [[10, 32]], 'text_spans_inner': [[21, 25]]}, 'preferred_term': {'logical_column_id': 0, 'value': 'Skin'}, 'ontology': {'logical_column_id': 0, 'value': 'nlm'}, 'node_id': {'logical_column_id': 0, 'value': 'D012867'}, 'category': {'logical_column_id': 1, 'value': 'BodyStructure'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'text': {'value': 'There was an obvious skin les ...

# %% [markdown]
# Similar to Example one, you could convert the JSON output into a pandas dataframe.

# %%
import pandas as pd

# initiate an empty dataframe
df = pd.DataFrame()
pd.set_option("display.max_rows", None, "display.max_columns", None, "display.width", 1000)

# Retrieve main results from the JSON response, please note this cell would fail if the request failed in the last step
for body_json in responses:
    results = body_json["results"]
    for result_dict in results:
        df_dict = {}
        for key, value_dict in result_dict.items():
            df_dict[key] = value_dict['value']
        df_dict["Doc ID"] = body_json["doc_id"]
        df = pd.concat([df, pd.DataFrame.from_records([{**df_dict}])], ignore_index=True)

# Check the dataframe
df.head(10)

# %% [markdown]
# That's it! Hope you find this tutorial useful! Bye!
