# %% [markdown]
# # IQVIA NLP - Healthcare Concepts
#
# ## API Description
# NLP with the ability to recognize key Healthcare concepts, whilst recognizing context and patterns in data such as drugs, disease, smoking categorization, which are relevant to healthcare organizations.
#
# ## Accessing the API
# In order to consume this API, you will first need to Request access to the Healthcare Concepts API via this link:
# https://api-marketplace.work.iqvia.com/s/communityapi/a085w00000zhFVKAA2/api-marketplaceiqvianlphealthcareconceptspreview
#
# Please refer to "API Documentation" to learn more about accessing and using the API.
#
# ## Notebook Description
# This notebook is designed to show users an example of using the Healthcare Concepts NLP API to extract features related to healthcare concepts such as populations and medications found in medical records.
#
# ### Authorization
# The instructions for getting your credentials and the API endpoint URL can be found under the section "Get Started" and "How to use the API" following this link: https://api-marketplace.work.iqvia.com/s/communityapi/a085w00000zhFVKAA2/api-marketplaceiqvianlphealthcareconceptspreview

# %%
import getpass

# Getting credentials
api_marketplace_url = input('Please enter the API URL: ').rstrip('/')

mkp_user = input("Marketplace clientId: ")
mkp_password = getpass.getpass("Marketplace clientSecret: ")
mkp_headers = {'clientId': mkp_user, 'clientSecret': mkp_password}

print("Thanks for inputting URL, your user name and password!")
# Out:
# Please enter the API URL: https://vt.eu-apim-devtest.solutions.iqvia.com/eu/multi/api/v2/coding/multi
# Marketplace clientId: 3c5b244fcc99407e9a31c1e21272e72d
# Marketplace clientSecret: ········
# Thanks for inputting URL, your user name and password!

# %% [markdown]
# ### Example one: Make a request with text string as input
# Healthcare Concepts NLP API expects the String as Request Data Type. This example shows how to make a request to the API with text strings as input.

# %%
import requests
import time

# Define input text
input_text = "HISTORY OF PRESENT ILLNESS:  This 60-year-old white male is referred to us by his medical physician with a complaint of recent finding of a both pancreatic lesion and lesions with left adrenal gland.  The patient's history dates back to at the end of the January of this past year when he began experiencing symptoms consistent with difficulty almost like a suffocating feeling whenever he would lie flat on his back.  He noticed whenever he would recline backwards, he would begin this feeling and it is so bad now that he can barely recline, very little before he has this feeling. He does have a history of frequent urination.  Has been followed by urologist for this.  There is no family history of pancreatic cancer.  There is a history of gallstone pancreatitis in the patient's sister. MEDICATIONS:  Include glipizide 5 mg b.i.d., metformin 500 mg b.i.d., Atacand 16 mg daily, metoprolol 25 mg b.i.d., Lipitor 10 mg daily, pantoprazole 40 mg daily, Flomax 0.4 mg daily, Detrol 4 mg daily, Zyrtec 10 mg daily, Advair Diskus 100/50 mcg one puff b.i.d., and fluticasone spray 50 mcg two sprays daily. PAST SURGICAL HISTORY:  He has not had any previous surgery."

# Make a request
print("Posting text strings...")
response = requests.post(api_marketplace_url, headers=mkp_headers, files={'source_data': input_text})

# Poll the API until results are available
while response.status_code == 202:
    print('Results are not available yet. Waiting 5 seconds before polling again...')
    time.sleep(5)
    run_identifier = response.json()['id']
    response = requests.get(url=f'{api_marketplace_url}/{run_identifier}', headers=headers)

# Check the response
if response.status_code != 200:
    raise Exception(f'Unexpected status code: {response.status_code}')
results = response.json()

# Print the results
print(f'Results: \n{results}\n')
# Out:
# Posting text strings...
# Results:
# [{'doc_id': 'source_data', 'results': [{'concept_1': {'logical_column_id': 0, 'value': '60-year-old', 'original_spans_outer': [[34, 45]], 'original_spans_inner': [[34, 45]], 'indexed_spans_outer': [[1656, 2057]], 'indexed_spans_inner': [[1656, 2057]], 'text_spans_outer': [[30, 41]], 'text_spans_inner': [[30, 41]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'Adults'}, 'ontology_1': {'logical_column_id': 0, 'value': 'age'}, 'node_id_1': {'logical_column_id': 0, 'value': 'age:60y'}, 'category_1': {'logical_column_id': 1, 'value': 'Age'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {'value': '... OF PRESENT ILLNESS : This 60-year-old white male is referred to ...'}}, {'concept_1': {'logical_column_id': 0, 'value': 'adrenal gland', 'original_spans_outer': [[185, 198]], 'original_spans_inner': [[185, 198]], 'indexed_spans_outer': [[7782, 8275]], 'indexed_spans_inner': [[7782, 8275]], 'text_spans_outer': [[33, 46]], 'text_spans_inner': [[33, 46]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'Adrenal Glands'}, 'ontology_1': {'logical_column_id': 0, 'value': 'nlm'}, 'node_id_1': {'logical_column_id': 0, 'value': 'D000311'}, 'category_1': {'logical_column_id': 1, 'value': 'BodyStructure'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {'value': '... lesion and lesions with left adrenal gland .'}}, {'concept_1': {'logical_column_id': 0, 'value': 'Advair', 'original_spans_outer': [[1016, 1022]], 'original_spans_inner': [[1016, 1022]], 'indexed_spans_outer': [[41880, 42091]], 'indexed_spans_inner': [[41880, 42091]], 'text_spans_outer': [[25, 31]], 'text_spans_inner': [[25, 31]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'fluticasone propionate + salmeterol'}, 'ontology_1': {'logical_column_id': 0, 'value': 'nci'}, 'node_id_1': {'logical_column_id': 0, 'value': 'salmeterol_+_fluticasone_propionate'}, 'category_1': {'logical_column_id': 1, 'value': 'MedicationName'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {'value': '... Zyrtec 10 mg daily , Advair Diskus 100 / 50 mcg ...'}}, {'concept_1': {'logical_column_id': 0, 'value': 'Atacand', 'original_spans_outer': [[863, 870]], 'original_spans_inner': [[863, 870]], 'indexed_spans_outer': [[35590, 35837]], 'indexed_spans_inner': [[35590, 35837]], 'text_spans_outer': [[30, 37]], 'text_spans_inner': [[30, 37]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'Agent Affecting Cardiovascular System'}, 'ontology_1': {'logical_column_id': 0, 'value': 'nci'}, 'node_id_1': {'logical_column_id': 0, 'value': 'C78274'}, 'category_1': {'logical_column_id': 1, 'value': 'MedicationClass'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {'value': '... met ...

# %% [markdown]
# Now that we have got the JSON response from the Healthcare Concepts NLP API, we could convert the useful information associated with the keys into a pandas dataframe.

# %%
import pandas as pd

# initiate an empty dataframe
df = pd.DataFrame()
pd.set_option("display.max_rows", None, "display.max_columns", None, "display.width", 1000)

# Retrieve main results from the JSON response, please note this cell would fail if the request failed in the last step
for inner_results in results:
    for result_dict in inner_results['results']:
        df_dict = {}
        for key, value_dict in result_dict.items():
            df_dict[key] = value_dict['value']
        df = pd.concat([df, pd.DataFrame.from_records([{**df_dict}])], ignore_index=True)

# Check the dataframe
df
# Out:
#                     concept_1                                  preferred_term_1    ontology_1                            node_id_1              category_1       certainty    relation      concept_2  preferred_term_2   ontology_2                  node_id_2 category_2                                               text
# 0                 60-year-old                                            Adults           age                              age:60y                     Age                                                                                                                  ... OF PRESENT ILLNESS : This 60-year-old whit...
# 1               adrenal gland                                    Adrenal Glands           nlm                              D000311           BodyStructure                                                                                                                   ... lesion and lesions with left adrenal gland .
# 2                      Advair               fluticasone propionate + salmeterol           nci  salmeterol_+_fluticasone_propionate          MedicationName                                                                                                                  ... Zyrtec 10 mg daily , Advair Diskus 100 / 5...
# 3                     Atacand             Agent Affecting Cardiovascular System           nci                               C78274         MedicationClass                                                                                                                  ... metformin 500 mg b.i.d. , Atacand 16 mg da...
# 4                     Atacand                             Candesartan Cilexetil           nci                               C28903          MedicationName                  DrugDosage    16 mg daily    16 mg every 1d  measurement    dosage-g:16 mg every 1d     Dosage  ... metformin 500 mg b.i.d. , Atacand 16 mg da...
# 5                        back                                              Back           nci                               C13062           BodyStructure                                                                                                                                   ... would lie flat on his back .
# 6                        back                                              Back           nlm                              D001415           BodyStructure                                                                                                                                   ... would lie flat on his back .
# 7                        back       Structure of back of trunk (body structure)        snomed                             77568009           BodyStructure                                                                                                                                   ... would lie flat on his back .
# 8                   complaint                                         Complaint           nci                              C176714        DiseaseOrSymptom                                                                                                                  ... his medical physician with a complaint of ...
# 9                   complaint                               Complaint (finding)        snomed                            409586006        DiseaseOrSymptom                                                                                                                  ... his medical physician with a complaint of ...
# 10                     Detrol                    Agent Affecting Nervous System           nci                               C78272         MedicationClass                                                                                                                  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 11                     Detrol                                       Tolterodine           nci                               C62083          MedicationName                  DrugDosage     4 mg daily     4 mg every 1d  measurement     dosage-g:4 mg every 1d     Dosage  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 12                     Detrol                              Tolterodine Tartrate           nci                               C29504          MedicationName                  DrugDosage     4 mg daily     4 mg every 1d  measurement     dosage-g:4 mg every 1d     Dosage  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 13                     Detrol                              Tolterodine Tartrate           nlm                           D000068737          MedicationName                  DrugDosage     4 mg daily     4 mg every 1d  measurement     dosage-g:4 mg every 1d     Dosage  ... Flomax 0.4 mg daily , Detrol 4 mg daily , ...
# 14                    finding                                           Finding           nci                                C3367        DiseaseOrSymptom                                                                                                                  ... with a complaint of recent finding of a bo...
# 15                     Flomax                    Agent Affecting Nervous System           nci                               C78272         MedicationClass                                                                                                                  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 16                     Flomax                                        Tamsulosin           nci                               C75055          MedicationName                  DrugDosage   0.4 mg daily   0.4 mg every 1d  measurement   dosage-g:0.4 mg every 1d     Dosage  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 17                     Flomax                                        Tamsulosin           nlm                           D000077409          MedicationName                  DrugDosage   0.4 mg daily   0.4 mg every 1d  measurement   dosage-g:0.4 mg every 1d     Dosage  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 18                     Flomax                          Tamsulosin Hydrochloride           nci                               C29486          MedicationName                  DrugDosage   0.4 mg daily   0.4 mg every 1d  measurement   dosage-g:0.4 mg every 1d     Dosage  ... pantoprazole 40 mg daily , Flomax 0.4 mg d...
# 19                fluticasone                                       Fluticasone           nci                               C61767          MedicationName                  DrugDosage         50 mcg           0.05 mg  measurement                  g:0.05 mg     Dosage  ... one puff b.i.d. , and fluticasone spray 50...
# 20                fluticasone                                       Fluticasone           nci                               C61767          MedicationName                                                                                                                  ... one puff b.i.d. , and fluticasone spray 50...
# 21                fluticasone                                       Fluticasone           nlm                           D000068298          MedicationName                  DrugDosage         50 mcg           0.05 mg  measurement                  g:0.05 mg     Dosage  ... one puff b.i.d. , and fluticasone spray 50...
# 22                fluticasone                                       Fluticasone           nlm                           D000068298          MedicationName                                                                                                                  ... one puff b.i.d. , and fluticasone spray 50...
# 23                fluticasone                           Fluticasone (substance)        snomed                            397192001          MedicationName                  DrugDosage         50 mcg           0.05 mg  measurement                  g:0.05 mg     Dosage  ... one puff b.i.d. , and fluticasone spray 50...
# 24                fluticasone                           Fluticasone (substance)        snomed                            397192001          MedicationName                                                                                                                  ... one puff b.i.d. , and fluticasone spray 50...
# 25                fluticasone                             Hormone Therapy Agent           nci                              C147908         MedicationClass                                                                                                                  ... one puff b.i.d. , and fluticasone spray 50...
# 26                fluticasone                           Immunotherapeutic Agent           nci                                 C308         MedicationClass                                                                                                                  ... one puff b.i.d. , and fluticasone spray 50...
# 27                  gallstone                                    Cholelithiasis        meddra                             10008629        DiseaseOrSymptom          Family                                                                                                  There is a history of gallstone pancreatitis i...
# 28                  gallstone                                    Cholelithiasis      nlm_plus                              D002769        DiseaseOrSymptom          Family                                                                                                  There is a history of gallstone pancreatitis i...
# 29                  gallstone                                        Gallstones      nlm_plus                              D042882        DiseaseOrSymptom          Family                                                                                                  There is a history of gallstone pancreatitis i...
# 30     gallstone pancreatitis                 Gallstone pancreatitis (disorder)        snomed                             95563007        DiseaseOrSymptom          Family                                                                                                  There is a history of gallstone pancreatitis i...
# 31                  glipizide    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                                                                                                                  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 32                  glipizide                                         Glipizide           nci                               C29074          MedicationName                  DrugDosage    5 mg b.i.d.    5 mg every 12h  measurement    dosage-g:5 mg every 12h     Dosage  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 33                  glipizide                                         Glipizide           nlm                              D005913          MedicationName                  DrugDosage    5 mg b.i.d.    5 mg every 12h  measurement    dosage-g:5 mg every 12h     Dosage  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 34                  glipizide                             Glipizide (substance)        snomed                            387143009          MedicationName                  DrugDosage    5 mg b.i.d.    5 mg every 12h  measurement    dosage-g:5 mg every 12h     Dosage  MEDICATIONS : Include glipizide 5 mg b.i.d. , ...
# 35                    ILLNESS                                           Illness        meddra                             10080284        DiseaseOrSymptom                                                                                                                  HISTORY OF PRESENT ILLNESS : This 60-year-old ...
# 36                    ILLNESS                                 Illness (finding)        snomed                             39104002        DiseaseOrSymptom                                                                                                                  HISTORY OF PRESENT ILLNESS : This 60-year-old ...
# 37  January of this past year                         January of this past year          date    PastMo: January of this past year                    Date                                                                                                                  ... at the end of the January of this past yea...
# 38         left adrenal gland                                Left Adrenal Gland           nci                               C49322           BodyStructure                                                                                                                  ... pancreatic lesion and lesions with left ad...
# 39         left adrenal gland  Structure of left adrenal gland (body structure)        snomed                             12003004           BodyStructure                                                                                                                  ... pancreatic lesion and lesions with left ad...
# 40                     lesion                                            Lesion           nci                                C3824        DiseaseOrSymptom                                                                                                                  ... finding of a both pancreatic lesion and le...
# 41                     lesion                               Wounds and Injuries      nlm_plus                              D014947        DiseaseOrSymptom                                                                                                                  ... finding of a both pancreatic lesion and le...
# 42                    lesions                               Wounds and Injuries      nlm_plus                              D014947        DiseaseOrSymptom                                                                                                                  ... a both pancreatic lesion and lesions with ...
# 43                    Lipitor    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                                                                                                                  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 44                    Lipitor                                      Atorvastatin           nci                               C61527          MedicationName                  DrugDosage    10 mg daily    10 mg every 1d  measurement    dosage-g:10 mg every 1d     Dosage  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 45                    Lipitor                                      Atorvastatin           nlm                           D000069059          MedicationName                  DrugDosage    10 mg daily    10 mg every 1d  measurement    dosage-g:10 mg every 1d     Dosage  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 46                    Lipitor                              Atorvastatin Calcium           nci                               C28837          MedicationName                  DrugDosage    10 mg daily    10 mg every 1d  measurement    dosage-g:10 mg every 1d     Dosage  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 47                    Lipitor                                  Enzyme Inhibitor           nci                                 C471         MedicationClass                                                                                                                  ... metoprolol 25 mg b.i.d. , Lipitor 10 mg da...
# 48                       male                                              Male                                                                     Gender                                                                                                                  ... ILLNESS : This 60-year-old white male is r...
# 49                  metformin    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                                                                                                                  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 50                  metformin                             Chemopreventive Agent           nci                                C1892         MedicationClass                                                                                                                  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 51                  metformin                                         Metformin           nci                               C61612          MedicationName                  DrugDosage  500 mg b.i.d.  500 mg every 12h  measurement  dosage-g:500 mg every 12h     Dosage  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 52                  metformin                                         Metformin           nlm                              D008687          MedicationName                  DrugDosage  500 mg b.i.d.  500 mg every 12h  measurement  dosage-g:500 mg every 12h     Dosage  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 53                  metformin                             Metformin (substance)        snomed                            372567009          MedicationName                  DrugDosage  500 mg b.i.d.  500 mg every 12h  measurement  dosage-g:500 mg every 12h     Dosage  ... glipizide 5 mg b.i.d. , metformin 500 mg b...
# 54                 metoprolol                    Agent Affecting Nervous System           nci                               C78272         MedicationClass                                                                                                                  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 55                 metoprolol                                        Metoprolol           nci                               C61845          MedicationName                  DrugDosage   25 mg b.i.d.   25 mg every 12h  measurement   dosage-g:25 mg every 12h     Dosage  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 56                 metoprolol                                        Metoprolol           nlm                              D008790          MedicationName                  DrugDosage   25 mg b.i.d.   25 mg every 12h  measurement   dosage-g:25 mg every 12h     Dosage  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 57                 metoprolol                            Metoprolol (substance)        snomed                            372826007          MedicationName                  DrugDosage   25 mg b.i.d.   25 mg every 12h  measurement   dosage-g:25 mg every 12h     Dosage  ... Atacand 16 mg daily , metoprolol 25 mg b.i...
# 58          pancreatic cancer                              Pancreatic Carcinoma           nci                                C3850        DiseaseOrSymptom         Negated                                                                                                  There is no family history of pancreatic cancer .
# 59          pancreatic cancer                              Pancreatic Carcinoma           nci                                C3850        DiseaseOrSymptom   NegatedFamily                                                                                                  There is no family history of pancreatic cancer .
# 60          pancreatic cancer                              Pancreatic Carcinoma           nci                                C3850        DiseaseOrSymptom  NegatedHistory                                                                                                  There is no family history of pancreatic cancer .
# 61          pancreatic cancer                              Pancreatic carcinoma        meddra                             10033609        DiseaseOrSymptom         Negated                                                                                                  There is no family history of pancreatic cancer .
# 62          pancreatic cancer                              Pancreatic carcinoma        meddra                             10033609        DiseaseOrSymptom   NegatedFamily                                                                                                  There is no family history of pancreatic cancer .
# 63          pancreatic cancer                              Pancreatic carcinoma        meddra                             10033609        DiseaseOrSymptom  NegatedHistory                                                                                                  There is no family history of pancreatic cancer .
# 64          pancreatic cancer                              Pancreatic Neoplasms      nlm_plus                              D010190        DiseaseOrSymptom         Negated                                                                                                  There is no family history of pancreatic cancer .
# 65          pancreatic cancer                              Pancreatic Neoplasms      nlm_plus                              D010190        DiseaseOrSymptom   NegatedFamily                                                                                                  There is no family history of pancreatic cancer .
# 66          pancreatic cancer                              Pancreatic Neoplasms      nlm_plus                              D010190        DiseaseOrSymptom  NegatedHistory                                                                                                  There is no family history of pancreatic cancer .
# 67               pancreatitis                                      Pancreatitis        meddra                             10033645        DiseaseOrSymptom          Family                                                                                                  ... is a history of gallstone pancreatitis in ...
# 68               pancreatitis                                      Pancreatitis           nci                                C3306        DiseaseOrSymptom          Family                                                                                                  ... is a history of gallstone pancreatitis in ...
# 69               pancreatitis                                      Pancreatitis      nlm_plus                              D010195        DiseaseOrSymptom          Family                                                                                                  ... is a history of gallstone pancreatitis in ...
# 70               pancreatitis                           Pancreatitis, CTCAE 3.0           nci                               C56602        DiseaseOrSymptom          Family                                                                                                  ... is a history of gallstone pancreatitis in ...
# 71               pancreatitis                           Pancreatitis, CTCAE 5.0           nci                              C146789        DiseaseOrSymptom          Family                                                                                                  ... is a history of gallstone pancreatitis in ...
# 72               pantoprazole    Agent Affecting Digestive System or Metabolism           nci                               C78276         MedicationClass                                                                                                                  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 73               pantoprazole                                      Pantoprazole           nci                               C29346          MedicationName                  DrugDosage    40 mg daily    40 mg every 1d  measurement    dosage-g:40 mg every 1d     Dosage  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 74               pantoprazole                                      Pantoprazole           nlm                           D000077402          MedicationName                  DrugDosage    40 mg daily    40 mg every 1d  measurement    dosage-g:40 mg every 1d     Dosage  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 75               pantoprazole                          Pantoprazole (substance)        snomed                            395821003          MedicationName                  DrugDosage    40 mg daily    40 mg every 1d  measurement    dosage-g:40 mg every 1d     Dosage  ... Lipitor 10 mg daily , pantoprazole 40 mg d...
# 76                     sister                                            Sister  Linguamatics                               sister          FamilyRelation                                                                                                                  ... gallstone pancreatitis in the patient's si...
# 77                suffocating                                          Asphyxia      nlm_plus                              D001237        DiseaseOrSymptom                                                                                                                  ... with difficulty almost like a suffocating ...
# 78                suffocating                             Suffocating (finding)        snomed                            271877004        DiseaseOrSymptom                                                                                                                  ... with difficulty almost like a suffocating ...
# 79        suffocating feeling                               Suffocation feeling        meddra                             10042444        DiseaseOrSymptom                                                                                                                  ... with difficulty almost like a suffocating ...
# 80                    surgery                                           Surgery        meddra                             10042609  TreatmentAndProcedures         Negated                                                                                                  ... SURGICAL HISTORY : He has not had any prev...
# 81                    surgery                                           Surgery        meddra                             10042609  TreatmentAndProcedures  NegatedHistory                                                                                                  ... SURGICAL HISTORY : He has not had any prev...
# 82                   symptoms                                           Symptom           nci                                C4876        DiseaseOrSymptom                                                                                                                  ... year when he began experiencing symptoms c...
# 83                the January                                                01          date                               Mo: 01                    Date                                                                                                                  ... to at the end of the January of this past ...
# 84                  urination                                         Urination           nlm                              D014554        DiseaseOrSymptom                                                                                                                         ... have a history of frequent urination .
# 85                      white                                             White  Linguamatics                                White         PopulationGroup                                                                                                                  ... PRESENT ILLNESS : This 60-year-old white m...
# 86                     Zyrtec                                        Cetirizine           nci                                C1042          MedicationName                  DrugDosage    10 mg daily    10 mg every 1d  measurement    dosage-g:10 mg every 1d     Dosage  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...
# 87                     Zyrtec                                        Cetirizine           nlm                              D017332          MedicationName                  DrugDosage    10 mg daily    10 mg every 1d  measurement    dosage-g:10 mg every 1d     Dosage  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...
# 88                     Zyrtec                          Cetirizine Hydrochloride           nci                               C28920          MedicationName                  DrugDosage    10 mg daily    10 mg every 1d  measurement    dosage-g:10 mg every 1d     Dosage  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...
# 89                     Zyrtec                           Immunotherapeutic Agent           nci                                 C308         MedicationClass                                                                                                                  ... Detrol 4 mg daily , Zyrtec 10 mg daily , A...

# %% [markdown]
# ### Example two: Make a request with a zip file as input

# %%
import os
import shutil
import zipfile
import time

# Define input zip location
input_zip = os.path.join(os.getcwd(), "demo_docs/HealthcareConcepts/HealthcareConcepts_demo.zip")

# Define a directory to extract the input zip file into
input_folder = os.path.join(os.getcwd(), "demo_docs/HealthcareConcepts/HealthcareConcepts_demo")
if os.path.isdir(input_folder):
    shutil.rmtree(input_folder)
os.mkdir(input_folder)

# Extract files from the input zip into the folder
with zipfile.ZipFile(input_zip, "r") as zip_ref:
    zip_ref.extractall(input_folder)
print(f"Documents extracted to: {input_folder}")

# Make a request with all extracted files
print("Posting text files from the zip file...")
all_results = []
for filename in os.listdir(input_folder):
    file_path = os.path.join(input_folder, filename)
    with open(file_path, "r") as file:
        print(f"Posting {filename}...")
        response = requests.post(api_marketplace_url, headers=mkp_headers, files={'source_data': file})
        
    # Poll the API until results are available
    while response.status_code == 202:
        print('Results are not available yet. Waiting 5 seconds before polling again...')
        time.sleep(5)
        run_identifier = response.json()['id']
        response = requests.get(url=f'{api_marketplace_url}/{run_identifier}', headers=headers)

    # Check the response
    if response.status_code != 200:
        raise Exception(f'Unexpected status code: {response.status_code}')
    all_results.append(response.json())

print("All done!")
print(f"All JSON responses are: {all_results}")
# Out:
# Documents extracted to: C:\Users\Hui.Feng\Documents\Git\api-marketplace-demo\demo_docs/HealthcareConcepts/HealthcareConcepts_demo
# Posting text files from the zip file...
# Posting M1.txt...
# Posting M2.txt...
# All done!
# All JSON responses are: [[{'doc_id': 'M1', 'results': [{'concept_1': {'logical_column_id': 0, 'value': 'a consultation', 'original_spans_outer': [[1121, 1135]], 'original_spans_inner': [[1123, 1135]], 'indexed_spans_outer': [[45967, 46514]], 'indexed_spans_inner': [[46051, 46514]], 'text_spans_outer': [[8, 22]], 'text_spans_inner': [[10, 22]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'Consultation (procedure)'}, 'ontology_1': {'logical_column_id': 0, 'value': 'snomed'}, 'node_id_1': {'logical_column_id': 0, 'value': '11429006'}, 'category_1': {'logical_column_id': 1, 'value': 'TreatmentAndProcedures'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {'value': 'This is a consultation for the patient in regards ...'}}, {'concept_1': {'logical_column_id': 0, 'value': 'A sterile dressing', 'original_spans_outer': [[959, 977]], 'original_spans_inner': [[969, 977]], 'indexed_spans_outer': [[39252, 39950]], 'indexed_spans_inner': [[39662, 39950]], 'text_spans_outer': [[0, 18]], 'text_spans_inner': [[10, 18]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'Application of dressing (procedure)'}, 'ontology_1': {'logical_column_id': 0, 'value': 'snomed'}, 'node_id_1': {'logical_column_id': 0, 'value': '3895009'}, 'category_1': {'logical_column_id': 1, 'value': 'TreatmentAndProcedures'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {'value': 'A sterile dressing was applied .'}}, {'concept_1': {'logical_column_id': 0, 'value': 'A sterile dressing', 'original_spans_outer': [[959, 977]], 'original_spans_inner': [[961, 968]], 'indexed_spans_outer': [[39252, 39950]], 'indexed_spans_inner': [[39334, 39941]], 'text_spans_outer': [[0, 18]], 'text_spans_inner': [[2, 9]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'Sterilisation'}, 'ontology_1': {'logical_column_id': 0, 'value': 'meddra'}, 'node_id_1': {'logical_column_id': 0, 'value': '10062116'}, 'category_1': {'logical_column_id': 1, 'value': 'TreatmentAndProcedures'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {'value': 'A sterile dressing was applied .'}}, {'concept_1': {'logical_column_id': 0, 'value': 'anesthetic', 'original_spans_outer': [[393, 403]], 'original_spans_inner': [[393, 403]], 'indexed_spans_outer': [[16140, 16510]], 'indexed_spans_inner': [[16140, 16510]], 'text_spans_outer': [[6, 16]], 'text_spans_inner': [[6, 16]]}, 'preferred_term_1': {'logical_column_id': 0, 'value': 'Agent Affecting Nervous System'}, 'ontology_1': {'logical_column_id': 0, 'value': 'nci'}, 'node_id_1': {'logical_column_id': 0, 'value': 'C78272'}, 'category_1': {'logical_column_id': 1, 'value': 'MedicationClass'}, 'certainty': {'logical_column_id': 2, 'value': ''}, 'relation': {'logical_column_id': 3, 'value': ''}, 'concept_2': {'logical_column_id': 4, 'value': ''}, 'preferred_term_2': {'logical_column_id': 4, 'value': ''}, 'ontology_2': {'logical_column_id': 4, 'value': ''}, 'node_id_2': {'logical_column_id': 4, 'value': ''}, 'category_2': {'logical_column_id': 5, 'value': ''}, 'text': {' ...

# %% [markdown]
# Similar to Example one, you could convert the JSON output into a pandas dataframe.

# %%
import pandas as pd

# initiate an empty dataframe
df = pd.DataFrame()
pd.set_option("display.max_rows", None, "display.max_columns", None, "display.width", 1000)

# Retrieve main results from the JSON response, please note this cell would fail if the request failed in the last step
for results in all_results:
    for inner_results in results:
        for result_dict in inner_results['results']:
            df_dict = {}
            df_dict["Doc ID"] = inner_results["doc_id"]
            for key, value_dict in result_dict.items():
                df_dict[key] = value_dict['value']
            df = pd.concat([df, pd.DataFrame.from_records([{**df_dict}])], ignore_index=True)

# Check the dataframe
df.head(10)
# Out:
#   Doc ID           concept_1                     preferred_term_1 ontology_1                                         node_id_1              category_1 certainty relation concept_2 preferred_term_2 ontology_2 node_id_2 category_2                                               text
# 0     M1      a consultation             Consultation (procedure)     snomed                                          11429006  TreatmentAndProcedures                                                                                This is a consultation for the patient in rega...
# 1     M1  A sterile dressing  Application of dressing (procedure)     snomed                                           3895009  TreatmentAndProcedures                                                                                                 A sterile dressing was applied .
# 2     M1  A sterile dressing                        Sterilisation     meddra                                          10062116  TreatmentAndProcedures                                                                                                 A sterile dressing was applied .
# 3     M1          anesthetic       Agent Affecting Nervous System        nci                                            C78272         MedicationClass                                                                                Local anesthetic medication was infiltrated ar...
# 4     M1          anesthetic                     Anesthetic Agent        nci                                              C245          MedicationName                                                                                Local anesthetic medication was infiltrated ar...
# 5     M1              biopsy                               Biopsy     meddra                                          10004720         ExaminationName   Negated                                                                      The patient had no neurovascular deficits , et...
# 6     M1              biopsy                               Biopsy     meddra                                          10004720         ExaminationName                                                                                  A punch biopsy of the worrisome skin lesion ...
# 7     M1              biopsy                               Biopsy        nlm  D001706_group_5_03c30202b65ddd016bc296f733d29065         ExaminationName   Negated                                                                      The patient had no neurovascular deficits , et...
# 8     M1              biopsy                               Biopsy        nlm  D001706_group_5_03c30202b65ddd016bc296f733d29065         ExaminationName                                                                                  A punch biopsy of the worrisome skin lesion ...
# 9     M1              biopsy                               Biopsy        nlm  D001706_group_8_27c3321442554cf1ea542b7093929b1b  TreatmentAndProcedures   Negated                                                                      The patient had no neurovascular deficits , et...

# %% [markdown]
# That's it! Hope you find this tutorial useful! Bye!
